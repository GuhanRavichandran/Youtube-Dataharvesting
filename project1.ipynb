# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="1997",
  auth_plugin='mysql_native_password',
  database='youtubedata'
)

mycursor = mydb.cursor()
# Out:
# ---------------------------------------------------------------------------
# NotSupportedError                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 mydb = mysql.connector.connect(
#       2   host="localhost",
#       3   user="root",
#       4   password="1997",
#       5   auth_plugin='mysql_native_password',
#       6   database='youtubedata'
#       7 )
#       9 mycursor = mydb.cursor()
#
# File c:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\__init__.py:179, in connect(*args, **kwargs)
#     177     return CMySQLConnection(*args, **kwargs)
#     178 else:
# --> 179     return MySQLConnection(*args, **kwargs)
#
# File c:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\connection.py:95, in MySQLConnection.__init__(self, *args, **kwargs)
#      92 self._pool_config_version = None
#      94 if len(kwargs) > 0:
# ---> 95     self.connect(**kwargs)
#
# ...

# %%
mycursor.execute("use youtubedata")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 cursorclass.execute("use youtubedata")
#
# NameError: name 'cursorclass' is not defined

# %%
 mycursor.execute("SHOW TABLES")

for x in mycursor:
  print(x)
# Out:
# ('comment_detail',)
# ('video_detail',)
# ('youtubedata',)

# %%
def channel_data(channel_id):
    channel_ids=[]
    request = youtube.channels().list(
    part="snippet,contentDetails,statistics",      
    id=channel_id
    )
    response = request.execute()
    
    data={
        "channel_name":response['items'][0]['snippet']['title'],
        "channel_id":channel_id,
        "publishedAT":response['items'][0]['snippet']['publishedAt'],
        "video_count":response['items'][0]['statistics']['videoCount'],
        "subscription_count":response['items'][0]['statistics']['subscriberCount'],
        "channel_views":response['items'][0]['statistics']['viewCount'],
        "channel_description":response['items'][0]['snippet']['description'],
        "playlist_id":response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    }
    channel_ids.append(data) 
    return channel_ids

# %%
ch_ids=channel_data('UCJcCB-QYPIBcbKcBQOTwhiA')

# %%
ch_ids
# Out:
# [{'channel_name': 'Vj Siddhu Vlogs',
#   'channel_id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'publishedAT': '2023-06-14T07:41:42.139364Z',
#   'video_count': '201',
#   'subscription_count': '2720000',
#   'channel_views': '448324521',
#   'channel_description': 'Hello guys! Welcome to my channel! !\n\nMy channel will take you into the details of my life and give a glimpse of what inspires me to do what I do. \n\nGet ready to watch my latest vlogs depicting life in detail that will make you slow down and enjoy life a little better. Subscribe to my channel and stay connected!  \n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n______________________________\n\nDigital Partner - Divo\nDivo is one of the leading digital media companies in South India working with brands and content creators across genres.\n',
#   'playlist_id': 'UUJcCB-QYPIBcbKcBQOTwhiA'}]

# %%
channel_id = []

# Process each dictionary in the list
for ch_id in ch_ids:
    # Create a tuple from dictionary values and append to video_data
    data = tuple(ch_id.values())
    channel_id.append(data)

# %%
channel_ids=channel_id

# %%
channel_ids
# Out:
# [('Vj Siddhu Vlogs',
#   'UCJcCB-QYPIBcbKcBQOTwhiA',
#   '2023-06-14T07:41:42.139364Z',
#   '201',
#   '2720000',
#   '448324521',
#   'Hello guys! Welcome to my channel! !\n\nMy channel will take you into the details of my life and give a glimpse of what inspires me to do what I do. \n\nGet ready to watch my latest vlogs depicting life in detail that will make you slow down and enjoy life a little better. Subscribe to my channel and stay connected!  \n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n______________________________\n\nDigital Partner - Divo\nDivo is one of the leading digital media companies in South India working with brands and content creators across genres.\n',
#   'UUJcCB-QYPIBcbKcBQOTwhiA')]

# %%
mycursor.execute("""
    CREATE TABLE Youtubedata (
        channel_name VARCHAR(100),
        channel_id VARCHAR(80) PRIMARY KEY,
        subscriber INT,
        views INT,
        Total_videos INT,
        channel_description TEXT,
        playlist_id VARCHAR(80)
    )
""")
mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\connection_cext.py:697, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     696         query = query.encode("utf-8")
# --> 697     self._cmysql.query(
#     698         query,
#     699         raw=raw,
#     700         buffered=buffered,
#     701         raw_as_string=raw_as_string,
#     702         query_attrs=self.query_attrs,
#     703     )
#     704 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Table 'youtubedata' already exists
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 mycursor.execute("""
#       2     CREATE TABLE Youtubedata (
# ...

# %%
def tables():
    Youtube_data()

# %%
mycursor = mydb.cursor()

# Define the SQL INSERT statement
sql = """
    INSERT INTO Youtubedata (channel_name, channel_id, subscriber, views, Total_videos, channel_description, playlist_id)
    VALUES (%s, %s, %s, %s, %s, %s, %s)
"""

# Define the values to be inserted
values = [
  
    (
        "Skills Maker TV",
        "UCgqFE36SRlascaK19bmYt8A",
        1190000,
        120228016,
        675,
        "Hello friends, Welcome to 'SkillsMakers tv', I created this channel on 16 May 2013, my motive behind creating this channel was to make Easy to Understand, Tech Videos in Tamil, and I wanted each and every Individual whoever is interested in technology to be able to understand it in the easiest possible way. I am a computer technician living in India, doing this as my Hobby, I post a new video weekly, on topics that create the most confusion. Please SUBSCRIBE to SkillsMakers tv. Thanks.\n\nVideo Topics:\n1)Mobile SETTINGS Tips Tricks in Tamil\n2)Mobile apps & computer software review in Tamil\n3)Internet Settings in Tamil\n4)How To Tutorials in Tamil\n5)Tech Explain in Tamil\n6)Computer in Tamil\n7)Gadgets Reviews unboxing & Comparison in Tamil\n\nI also have one more channel (Skills Maker TV Shorts) which is all about our life channel. Please don’t forget to subscribe to this also.\n\nFor Business enquiries: skillmaker05@gmail.com\n\nI do not provide tech support over e-mail.",
        "UUgqFE36SRlascaK19bmYt8A"
    )
]

# Execute the SQL statement with the values
mycursor.executemany(sql, values)

# Commit the transaction
mydb.commit()

# Close the cursor and connection
mycursor.close()
mydb.close()

print(mycursor.rowcount, "records inserted.")
# Out:
# 1 records inserted.

# %%
# Create a cursor object
mycursor = mydb.cursor()

# Define the SQL INSERT statement
sql = """
    INSERT INTO Youtubedata (channel_name, channel_id, subscriber, views, Total_videos, channel_description, playlist_id)
    VALUES (%s, %s, %s, %s, %s, %s, %s)
"""

# Define the values to be inserted
values =channel_ids

# Execute the SQL statement with the values
mycursor.executemany(sql, values)

# Commit the transaction
mydb.commit()

# Close the cursor and connection
mycursor.close()
mydb.close()

print(mycursor.rowcount, "records inserted.")

# %%
# Create a cursor object
mycursor = mydb.cursor()

# Define the SQL INSERT statement
sql = """
    INSERT INTO Youtubedata (channel_name, channel_id, subscriber, views, Total_videos, channel_description, playlist_id)
    VALUES (%s, %s, %s, %s, %s, %s, %s)
"""

# Define the values to be inserted
values = [
    (
        "Vj Siddhu Vlogs",
        "UCJcCB-QYPIBcbKcBQOTwhiA",
        2710000,
        1441747099,
        199,
        "Hello guys! Welcome to my channel! My channel will take you into the details of my life and give a glimpse of what inspires me to do what I do. Get ready to watch my latest vlogs depicting life in detail that will make you slow down and enjoy life a little better. Subscribe to my channel and stay connected! For Business inquiries please contact us: 7200571056 Gmail: vjsidduvlogsadv@gmail.com Digital Partner - Divo Divo is one of the leading digital media companies in South India working with brands and content creators across genre.",
        "UUJcCB-QYPIBcbKcBQOTwhiA"
    ),
    (
        "Irfan's view",
        "UCnjU1FHmao9YNfPzE039YTw",
        4360000,
        1415118888,
        2499,
        "I love Food and Living. So, I vlog and do Food Reviews.",
        "UCgqFE36SRlascaK19bmYt8A"
    ),
    (
        "Peppa Foodie",
        "UC8wwXAm77RNzVN-cJOy8t8g",
        1770000,
        1264901941,
        1331,
        "Vanakam Makkale ;-) This is your Boy Peppa Here xD 🤟🏻✨ and this is a Public Space to Share all My Food 🍜🥢🍣🍕 & Travel Adventures ✈️🛳 So Sit back and Enjoy the Videos and if you Happen to Like them Do Subscribe xD",
        "UU8wwXAm77RNzVN-cJOy8t8g"
    ),
    (
        "Gpmuthu Official",
        "UCkHngIP8_GpujNDSdUfhETw",
        1620000,
        331446299,
        1029,
        "For Business Enquiries - skanmstudio1984@gmail.com",
        "UUkHngIP8_GpujNDSdUfhETw"
    ),
    (
        "Shabarinath Premlal",
        "UCQqmjKQBKQkRbWbSntYJX0Q",
        210,
        2600,
        10,
        "",
        "UUQqmjKQBKQkRbWbSntYJX0Q"
    ),
    (
        "Ishwarya Mahesh kumar",
        "UCzFN1MbdBvcNNHiJpa3hm2g",
        10700,
        3887348,
        260,
        "",
        "UUzFN1MbdBvcNNHiJpa3hm2g"
    ),
    (
        "kk abirami vlog",
        "UC9zWJT-ftzVNfeng8bZACNw",
        2230,
        392025,
        595,
        "Kk abirami vlog",
        "UU9zWJT-ftzVNfeng8bZACNw"
    ),
    (
        "Abarnasivabalan vlogs",
        "UC-XZPyAjTd9oLGF7brGrD2g",
        417000,
        212291299,
        469,
        "My daily vlogs",
        "UU-XZPyAjTd9oLGF7brGrD2g"
    )
]

# Execute the SQL statement with the values
mycursor.executemany(sql, values)

# Commit the transaction
mydb.commit()

# Close the cursor and connection
mycursor.close()
mydb.close()

print(mycursor.rowcount, "records inserted.")
# Out:
# 8 records inserted.

# %%
import googleapiclient.discovery
api_service_name = "youtube"
api_version = "v3"
api_key="AIzaSyBMXvNN-k7uLBWlbaFYF5b1iMpp_ZO1ehc"
youtube = googleapiclient.discovery.build(
        api_service_name, api_version,developerKey=api_key)

# %%
def get_video_id(channel_id):
    request = youtube.channels().list(
    part="contentDetails",
    id=channel_id
    )
    response=request.execute() 
    playlist_Id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    response1=youtube.playlistItems().list(part='snippet',
                                           playlistId=playlist_Id,maxResults=50).execute()
    video_id=[]
    for i in range(len(response1['items'])):
        video_id.append(response1['items'][i]['snippet']['resourceId']['videoId'])
    return video_id

# %%
video_id=get_video_id("UC8wwXAm77RNzVN-cJOy8t8g")

# %%
def get_video_detail(video_id):
    detail=[]
    for video_ids in video_id: 
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=video_id
        )
        response2 = request.execute()
    
        for item in response2['items']:  
                data = {
                    "channel_name": item['snippet']['channelTitle'],
                    "video_id": item['id'],
                    "title": item['snippet']['title'],  
                    "View_count": item['statistics'].get('viewCount', '0'),
                    "like_count": item['statistics'].get('likeCount', '0'),
                    "comments_count": item['statistics'].get('commentCount', '0'),
                }
                detail.append(data)
        return detail

# %%
videos=get_video_detail(video_id)

# %%
videos
# Out:
# [{'channel_name': 'Peppa Foodie',
#   'video_id': '2u8qlSBykYY',
#   'title': 'SECRET 🤫 Sweet of Chennai 🤯‼️| #shorts',
#   'View_count': '91450',
#   'like_count': '12833',
#   'comments_count': '13'},
#  {'channel_name': 'Peppa Foodie',
#   'video_id': '2r9UJa_EAHA',
#   'title': 'Trivandrum Chicken Fry ✨🔥⁉️| #shorts',
#   'View_count': '69169',
#   'like_count': '10901',
#   'comments_count': '17'},
#  {'channel_name': 'Peppa Foodie',
#   'video_id': 'wqCa4BkEgbo',
#   'title': '₹100 Ku SRM Students Atti Spot 🔥🙌🏻 | #shorts',
#   'View_count': '104318',
#   'like_count': '11920',
#   'comments_count': '17'},
#  {'channel_name': 'Peppa Foodie',
#   'video_id': 'J6qsAGQaSsM',
#   'title': 'Budget-ல துணி Vangnuma ⁉️👔✨| #shorts',
#   'View_count': '38130',
#   'like_count': '3645',
#   'comments_count': '11'},
#  {'channel_name': 'Peppa Foodie',
#   'video_id': 'EkNDYiAFXrc',
#   'title': 'Katchi Sera ❌ Aasa Kooda ✅ | #shorts',
#   'View_count': '34561',
#   'like_count': '3770',
# ...

# %%
video_data = []

# Process each dictionary in the list
for video in videos:
    # Create a tuple from dictionary values and append to video_data
    data = tuple(video.values())
    video_data.append(data)

# %%
videos=video_data

# %%
videos
# Out:
# [('Peppa Foodie',
#   '2u8qlSBykYY',
#   'SECRET 🤫 Sweet of Chennai 🤯‼️| #shorts',
#   '91450',
#   '12833',
#   '13'),
#  ('Peppa Foodie',
#   '2r9UJa_EAHA',
#   'Trivandrum Chicken Fry ✨🔥⁉️| #shorts',
#   '69169',
#   '10901',
#   '17'),
#  ('Peppa Foodie',
#   'wqCa4BkEgbo',
#   '₹100 Ku SRM Students Atti Spot 🔥🙌🏻 | #shorts',
#   '104318',
#   '11920',
#   '17'),
#  ('Peppa Foodie',
#   'J6qsAGQaSsM',
#   'Budget-ல துணி Vangnuma ⁉️👔✨| #shorts',
#   '38130',
#   '3645',
#   '11'),
#  ('Peppa Foodie',
#   'EkNDYiAFXrc',
#   'Katchi Sera ❌ Aasa Kooda ✅ | #shorts',
#   '34561',
#   '3770',
#   '7'),
#  ('Peppa Foodie',
#   '0OCKR1nZSRY',
#   'SECRET 🤫 Gravy of Chennai 🔥 | #shorts',
#   '168267',
#   '19802',
#   '66'),
#  ('Peppa Foodie',
#   'pYskowMXyRc',
#   'The Best Tiramisu in Chennai ✨🛐🔥 | GOAT -  Episode 2',
#   '11104',
#   '455',
#   '12'),
#  ('Peppa Foodie',
#   'A_7mX0BO7M8',
#   'Sundal மாமா Oru Vibe ✨😍🔥| #shorts',
#   '1094442',
#   '121009',
#   '163'),
# ...

# %%
mycursor.execute("DROP TABLE Video_detail")
mydb.commit()

# %%
mycursor.execute("""
    CREATE TABLE video_detail (
        channel_name VARCHAR(100),
        video_id VARCHAR(80),
        title VARCHAR(255),
        views INT,
        likes INT,
        comments INT
    )
""")
mydb.commit()

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="1997",
  auth_plugin='mysql_native_password',
  database='youtubedata'
)

mycursor = mydb.cursor()

# %%
sql = """
    INSERT INTO video_detail (channel_name, video_id, title, views, likes, comments)
    VALUES (%s, %s, %s, %s, %s, %s)
"""
values=videos

try:
    mycursor.executemany(sql, values)
    mydb.commit()
    print(mycursor.rowcount, "records inserted.")
except mysql.connector.Error as error:
    print(f"Error inserting data into MySQL table: {error}")
finally:
    mycursor.close()
    mydb.close()
# Out:
# 50 records inserted.

# %%
def comment_details(video_id):
    getcomments=[]
    for video_ids in video_id:
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_ids,
            maxResults=50
        )
        response3 = request.execute()
        
        for item in response3['items']:
            data = {
                "video_id":item['snippet']['topLevelComment']['snippet']['videoId'],
                "comment_id": item['snippet']['topLevelComment']['id'],
                "comment_text": item['snippet']['topLevelComment']['snippet']['textDisplay'],
                "comment_author": item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
            }
            getcomments.append(data)
        return getcomments

# %%
comments=comment_details(video_id)

# %%
comments
# Out:
# [{'video_id': '2u8qlSBykYY',
#   'comment_id': 'Ugzh2_TyGyvvboPnXNt4AaABAg',
#   'comment_text': 'My favourite combo ❤ whenever I visit Chennai I do enjoy both the places',
#   'comment_author': '@kishandin'},
#  {'video_id': '2u8qlSBykYY',
#   'comment_id': 'UgzyjsJSnR9NnCOY6jJ4AaABAg',
#   'comment_text': 'Shree mithai layum kedaikum',
#   'comment_author': '@venki3deditor'},
#  {'video_id': '2u8qlSBykYY',
#   'comment_id': 'UgwsoOSOVQXGp_ooheJ4AaABAg',
#   'comment_text': 'Now Agarwal bawan is open in Santhi colony, Anna Nagar',
#   'comment_author': '@rabbani4u'},
#  {'video_id': '2u8qlSBykYY',
#   'comment_id': 'Ugyd5G5TFCgIDdSHkUd4AaABAg',
#   'comment_text': 'Mixed with vadakkans love ah',
#   'comment_author': '@greensand7366'},
#  {'video_id': '2u8qlSBykYY',
#   'comment_id': 'UgzFpy05nVTJekH9GXx4AaABAg',
#   'comment_text': 'Chennai LA romba rare kadalai mittai😂😂😂',
#   'comment_author': '@vigneshnagaraj7137'},
#  {'video_id': '2u8qlSBykYY',
# ...

# %%
comment_data = []

# Process each dictionary in the list
for comment in comments:
    # Create a tuple from dictionary values and append to video_data
    data = tuple(comment.values())
    comment_data.append(data)

# %%
comment=comment_data

# %%
comment
# Out:
# [('2u8qlSBykYY',
#   'Ugzh2_TyGyvvboPnXNt4AaABAg',
#   'My favourite combo ❤ whenever I visit Chennai I do enjoy both the places',
#   '@kishandin'),
#  ('2u8qlSBykYY',
#   'UgzyjsJSnR9NnCOY6jJ4AaABAg',
#   'Shree mithai layum kedaikum',
#   '@venki3deditor'),
#  ('2u8qlSBykYY',
#   'UgwsoOSOVQXGp_ooheJ4AaABAg',
#   'Now Agarwal bawan is open in Santhi colony, Anna Nagar',
#   '@rabbani4u'),
#  ('2u8qlSBykYY',
#   'Ugyd5G5TFCgIDdSHkUd4AaABAg',
#   'Mixed with vadakkans love ah',
#   '@greensand7366'),
#  ('2u8qlSBykYY',
#   'UgzFpy05nVTJekH9GXx4AaABAg',
#   'Chennai LA romba rare kadalai mittai😂😂😂',
#   '@vigneshnagaraj7137'),
#  ('2u8qlSBykYY',
#   'UgzsdBlTOmaraGcgYdV4AaABAg',
#   'Badshah enum super ah irukum try paniparunga',
#   '@subramanigomathi8470'),
#  ('2u8qlSBykYY',
#   'UgzvcZPC3oIzK-l-o0d4AaABAg',
#   'Ghewar❤',
#   '@emceeakshayiyer3426'),
#  ('2u8qlSBykYY',
#   'UgzowNqhhALDXX6r61N4AaABAg',
#   '999th like and 6th comment 🎉',
#   '@LUCKY_GAMER664'),
# ...

# %%
mycursor.execute("""
    CREATE TABLE comment_detail (
        video_id varchar(80),
        comment_id varchar(80),
        comments Text,
        comment_author varchar(30)
         )
""")
mydb.commit()

# %%
sql = """
    INSERT INTO comment_detail (video_id,comment_id,comments,comment_author)
    VALUES (%s,%s,%s,%s)
"""

values =comment

try:
    mycursor.executemany(sql, values)
    mydb.commit()
    print(mycursor.rowcount, "records inserted.")


except mysql.connector.Error as error:
    print(f"Error inserting data into MySQL table: {error}")

finally:
    mycursor.close()
    mydb.close()
# Out:
# 13 records inserted.

# %%
import streamlit as st

# %%
with st.sidebar:
    st.title(":red[Youtube Data Harvesting]")
    st.header("Take Away codes")
    st.caption("python scripting")
    st.caption("Data collection")
    st.caption("API integration")
    st.caption("Data management using Mysql")
    
channel_id=st.text_input("Enter the channel_id")
    

st.button("Migrate to MYSQL")
show_tables=st.radio("select table for view",("channels","Videos","comments"))
# Out:
# 2024-06-22 06:43:53.766
# ...
#   command:
#
#     streamlit run C:\Users\Hp\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-06-22 06:43:53.766 Session state does not function when running a script without `streamlit run`
